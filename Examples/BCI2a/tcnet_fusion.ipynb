# %% [markdown]
# <a href="https://colab.research.google.com/github/UN-GCPDS/python-gcpds.EEG_Tensorflow_models/blob/main/Examples/BCI2a/tcnet_fusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BCI2a

# %%
# !pip install -U git+https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models.git >/dev/null

# %%
from EEG_Tensorflow_models.Utils.LoadData import load_dataset
from EEG_Tensorflow_models.Utils.Callbacks import get_callbacks
from EEG_Tensorflow_models.Utils.TrainingModels import get_loss,get_model,get_optimizer,train_model_cv

# %%
import numpy as np
import pickle
from scipy.signal import resample

# %% [markdown]
# # Exp 1: Schirmeister 2017

# %%
opt_args = {'lr':0.0009,'beta_1': 0.9}
optimizer = get_optimizer('Adam',opt_args)

loss = get_loss('CategoricalCrossentropy')

metrics = ['accuracy']

callbacks_names = {'early_stopping_train':'early_stopping','checkpoint_train':'checkpoint',
                'Threshold_valid':'Threshold','checkpoint_valid':'checkpoint',
                'early_stopping_valid':'early_stopping'}


Experiment = 'schirrmeister2017'
model_name = 'TCNet_fusion'

subjects = np.arange(1,10)
Acc = []
History = []
Subject = []
for sbj in subjects:
    print('Subject: {:d} of {:d}'.format(sbj,len(subjects)))

    X_train,y_train,X_valid,y_valid,fs = load_dataset(dataset_name="BNCI2014001", subject_id=sbj)
    
    #X_train = resample(X_train,int((X_train.shape[-2]/fs)*fs_new),axis=-2)    
    #X_valid = resample(X_valid,int((X_valid.shape[-2]/fs)*fs_new),axis=-2)     
        
    model_args = {'nb_classes':4,'Chans':X_train.shape[1],'Samples':X_train.shape[2],'layers':2,'kernel_s':4,'filt':12,'dropout':0.3,'activation':'elu','F1':24,'D':2,'kernLength':32,'dropout_eeg':0.3}
    model = get_model(model_name,model_args)
    
    call_args = [{'monitor':'val_accuracy','patience':100,'min_delta':0.001,'mode':'max','verbose':1,'restore_best_weights':False},
                {'filepath':'/kaggle/tmp/checkpoint_sbj_'+str(sbj),'save_format':'tf','monitor':'val_accuracy','verbose':1,'save_weights_only':True,'save_best_only':True},
                {'threshold':None},
                {'filepath':'/kaggle/tmp/checkpoint_2_sbj_'+str(sbj),'save_format':'tf','monitor':'val_accuracy','verbose':1,'save_weights_only':True,'save_best_only':True},
                {'monitor':'val_accuracy','patience':None,'min_delta':0.001,'mode':'max','verbose':1,'restore_best_weights':True}]
                
    callbacks = get_callbacks(callbacks_names,call_args)

    cv = train_model_cv(model,optimizer,loss,metrics,callbacks=callbacks)

    history = cv.fit_validation(X_train,y_train,X_val=X_valid,y_val=y_valid,batch_size=64,epochs=1000,verbose=1,val_mode=Experiment)
    acc = cv.get_accuracy()
    print('Subject accuracy: {:f}'.format(acc))
    Acc.append(acc)
    History.append(History)
    Subject.append(sbj)

    results = {}
    results['subject'] = Subject
    results['history'] = History
    results['accuracy'] = Acc

    with open('Results_BCI2a_'+Experiment+'_'+model_name+'.p','wb') as handle:
        pickle.dump(results,handle)
    
    del cv,callbacks,X_train,y_train,X_valid,y_valid,fs
# Out:
# /opt/conda/lib/python3.7/site-packages/moabb/datasets/download.py:53: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_BNCI_PATH"
#   set_config(key, get_config("MNE_DATA"))
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01T.mat' to file '/root/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01T.mat'.
# Subject: 1 of 9
# MNE_DATA is not already configured. It will be set to default location in the home directory - /root/mne_data
# All datasets will be downloaded to this location, if anything is already downloaded, please move manually to this location
# SHA256 hash of downloaded file: 054f02e70cf9c4ada1517e9b9864f45407939c1062c6793516585c6f511d0325
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01E.mat' to file '/root/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01E.mat'.
# SHA256 hash of downloaded file: 53d415f39c3d7b0c88b894d7b08d99bcdfe855ede63831d3691af1a45607fb62
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# 48 events found
# Event IDs: [1 2 3 4]
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function scale is deprecated; will be removed in 0.7.0. Use numpy.multiply instead.
#   warnings.warn(msg, category=FutureWarning)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 38 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 38.00 Hz
# - Upper transition bandwidth: 9.50 Hz (-6 dB cutoff frequency: 42.75 Hz)
# - Filter length: 413 samples (1.652 sec)
#
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['feet', 'left_hand', 'right_hand', 'tongue']
# Adding metadata with 4 columns
# Replacing existing metadata with 4 columns
# 48 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 48 events and 1125 original time points ...
# 0 bad epochs dropped
# 2021-09-30 04:23:15.596282: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-30 04:23:15.599798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-30 04:23:15.642665: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.643306: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-30 04:23:15.643385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-30 04:23:15.668852: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-30 04:23:15.668959: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-30 04:23:15.686450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-30 04:23:15.695324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-30 04:23:15.723147: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-30 04:23:15.730831: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-30 04:23:15.733500: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-30 04:23:15.733690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.734491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.736115: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-30 04:23:15.736845: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-30 04:23:15.737063: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-30 04:23:15.737231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.737854: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2021-09-30 04:23:15.737919: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-30 04:23:15.737950: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-30 04:23:15.737974: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-30 04:23:15.737998: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-30 04:23:15.738021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-30 04:23:15.738044: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-30 04:23:15.738069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-30 04:23:15.738092: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-30 04:23:15.738184: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.738853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:15.739386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-30 04:23:15.740478: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-30 04:23:22.101377: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-30 04:23:22.101427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-30 04:23:22.101441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-30 04:23:22.103959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:22.105042: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:22.106076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-30 04:23:22.107012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14387 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2021-09-30 04:23:22.898887: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-30 04:23:22.910801: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2000170000 Hz
# Epoch 1/1000
# 2021-09-30 04:23:24.935829: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-30 04:23:25.671440: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-30 04:23:25.697650: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 4/4 [==============================] - 9s 369ms/step - loss: 1.4941 - accuracy: 0.2495 - val_loss: 1.3865 - val_accuracy: 0.1897
#
# Epoch 00001: val_accuracy improved from -inf to 0.18966, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 2/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 1.3605 - accuracy: 0.3332 - val_loss: 1.3864 - val_accuracy: 0.1897
#
# Epoch 00002: val_accuracy did not improve from 0.18966
# Epoch 3/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2917 - accuracy: 0.4699 - val_loss: 1.3865 - val_accuracy: 0.1897
#
# Epoch 00003: val_accuracy did not improve from 0.18966
# Epoch 4/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2829 - accuracy: 0.4774 - val_loss: 1.3870 - val_accuracy: 0.1897
#
# Epoch 00004: val_accuracy did not improve from 0.18966
# Epoch 5/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.2277 - accuracy: 0.5478 - val_loss: 1.3884 - val_accuracy: 0.2931
#
# Epoch 00005: val_accuracy improved from 0.18966 to 0.29310, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 6/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 1.1488 - accuracy: 0.6246 - val_loss: 1.3918 - val_accuracy: 0.3103
#
# Epoch 00006: val_accuracy improved from 0.29310 to 0.31034, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 7/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 1.0815 - accuracy: 0.6817 - val_loss: 1.3989 - val_accuracy: 0.3103
#
# Epoch 00007: val_accuracy did not improve from 0.31034
# Epoch 8/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.9849 - accuracy: 0.6663 - val_loss: 1.4131 - val_accuracy: 0.3103
#
# Epoch 00008: val_accuracy did not improve from 0.31034
# Epoch 9/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.9406 - accuracy: 0.6419 - val_loss: 1.4338 - val_accuracy: 0.3103
#
# Epoch 00009: val_accuracy did not improve from 0.31034
# Epoch 10/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.8887 - accuracy: 0.6845 - val_loss: 1.4612 - val_accuracy: 0.3103
#
# Epoch 00010: val_accuracy did not improve from 0.31034
# Epoch 11/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.8634 - accuracy: 0.6763 - val_loss: 1.4871 - val_accuracy: 0.3103
#
# Epoch 00011: val_accuracy did not improve from 0.31034
# Epoch 12/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.8003 - accuracy: 0.7116 - val_loss: 1.5159 - val_accuracy: 0.3103
#
# Epoch 00012: val_accuracy did not improve from 0.31034
# Epoch 13/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.8101 - accuracy: 0.6816 - val_loss: 1.5400 - val_accuracy: 0.3103
#
# Epoch 00013: val_accuracy did not improve from 0.31034
# Epoch 14/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.7609 - accuracy: 0.6845 - val_loss: 1.5623 - val_accuracy: 0.3103
#
# Epoch 00014: val_accuracy did not improve from 0.31034
# Epoch 15/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.7713 - accuracy: 0.6941 - val_loss: 1.5843 - val_accuracy: 0.3103
#
# Epoch 00015: val_accuracy did not improve from 0.31034
# Epoch 16/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.7156 - accuracy: 0.7404 - val_loss: 1.6046 - val_accuracy: 0.3103
#
# Epoch 00016: val_accuracy did not improve from 0.31034
# Epoch 17/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.6920 - accuracy: 0.7406 - val_loss: 1.6372 - val_accuracy: 0.3103
#
# Epoch 00017: val_accuracy did not improve from 0.31034
# Epoch 18/1000
# 4/4 [==============================] - 0s 71ms/step - loss: 0.7088 - accuracy: 0.6972 - val_loss: 1.6696 - val_accuracy: 0.3103
#
# Epoch 00018: val_accuracy did not improve from 0.31034
# Epoch 19/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.6838 - accuracy: 0.7166 - val_loss: 1.6872 - val_accuracy: 0.3103
#
# Epoch 00019: val_accuracy did not improve from 0.31034
# Epoch 20/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.6468 - accuracy: 0.7344 - val_loss: 1.7112 - val_accuracy: 0.3103
#
# Epoch 00020: val_accuracy did not improve from 0.31034
# Epoch 21/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.6652 - accuracy: 0.7721 - val_loss: 1.7386 - val_accuracy: 0.3103
#
# Epoch 00021: val_accuracy did not improve from 0.31034
# Epoch 22/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.6503 - accuracy: 0.7535 - val_loss: 1.7587 - val_accuracy: 0.3103
#
# Epoch 00022: val_accuracy did not improve from 0.31034
# Epoch 23/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.6334 - accuracy: 0.7559 - val_loss: 1.7689 - val_accuracy: 0.3103
#
# Epoch 00023: val_accuracy did not improve from 0.31034
# Epoch 24/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5854 - accuracy: 0.7919 - val_loss: 1.7948 - val_accuracy: 0.3103
#
# Epoch 00024: val_accuracy did not improve from 0.31034
# Epoch 25/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.5544 - accuracy: 0.8032 - val_loss: 1.8194 - val_accuracy: 0.3103
#
# Epoch 00025: val_accuracy did not improve from 0.31034
# Epoch 26/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5443 - accuracy: 0.8535 - val_loss: 1.8434 - val_accuracy: 0.3103
#
# Epoch 00026: val_accuracy did not improve from 0.31034
# Epoch 27/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.5949 - accuracy: 0.7439 - val_loss: 1.8566 - val_accuracy: 0.3103
#
# Epoch 00027: val_accuracy did not improve from 0.31034
# Epoch 28/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5632 - accuracy: 0.8047 - val_loss: 1.8955 - val_accuracy: 0.3103
#
# Epoch 00028: val_accuracy did not improve from 0.31034
# Epoch 29/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5441 - accuracy: 0.8079 - val_loss: 1.9428 - val_accuracy: 0.3103
#
# Epoch 00029: val_accuracy did not improve from 0.31034
# Epoch 30/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5053 - accuracy: 0.8230 - val_loss: 2.0160 - val_accuracy: 0.3276
#
# Epoch 00030: val_accuracy improved from 0.31034 to 0.32759, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 31/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.4782 - accuracy: 0.8450 - val_loss: 2.0794 - val_accuracy: 0.3103
#
# Epoch 00031: val_accuracy did not improve from 0.32759
# Epoch 32/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.5189 - accuracy: 0.8004 - val_loss: 2.0658 - val_accuracy: 0.3276
#
# Epoch 00032: val_accuracy did not improve from 0.32759
# Epoch 33/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.4865 - accuracy: 0.8344 - val_loss: 2.0428 - val_accuracy: 0.3103
#
# Epoch 00033: val_accuracy did not improve from 0.32759
# Epoch 34/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.5044 - accuracy: 0.8070 - val_loss: 2.0318 - val_accuracy: 0.3103
#
# Epoch 00034: val_accuracy did not improve from 0.32759
# Epoch 35/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.5035 - accuracy: 0.8308 - val_loss: 2.0471 - val_accuracy: 0.4138
#
# Epoch 00035: val_accuracy improved from 0.32759 to 0.41379, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 36/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4863 - accuracy: 0.7872 - val_loss: 2.1075 - val_accuracy: 0.4138
#
# Epoch 00036: val_accuracy did not improve from 0.41379
# Epoch 37/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4819 - accuracy: 0.8582 - val_loss: 2.1747 - val_accuracy: 0.3276
#
# Epoch 00037: val_accuracy did not improve from 0.41379
# Epoch 38/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4489 - accuracy: 0.8414 - val_loss: 2.2134 - val_accuracy: 0.3103
#
# Epoch 00038: val_accuracy did not improve from 0.41379
# Epoch 39/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4393 - accuracy: 0.8320 - val_loss: 2.2559 - val_accuracy: 0.3966
#
# Epoch 00039: val_accuracy did not improve from 0.41379
# Epoch 40/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3656 - accuracy: 0.9088 - val_loss: 2.2738 - val_accuracy: 0.3966
#
# Epoch 00040: val_accuracy did not improve from 0.41379
# Epoch 41/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3632 - accuracy: 0.9053 - val_loss: 2.3323 - val_accuracy: 0.3103
#
# Epoch 00041: val_accuracy did not improve from 0.41379
# Epoch 42/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4063 - accuracy: 0.8709 - val_loss: 2.3741 - val_accuracy: 0.3621
#
# Epoch 00042: val_accuracy did not improve from 0.41379
# Epoch 43/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3854 - accuracy: 0.8737 - val_loss: 2.4306 - val_accuracy: 0.3793
#
# Epoch 00043: val_accuracy did not improve from 0.41379
# Epoch 44/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3839 - accuracy: 0.8883 - val_loss: 2.4269 - val_accuracy: 0.3103
#
# Epoch 00044: val_accuracy did not improve from 0.41379
# Epoch 45/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.4045 - accuracy: 0.8709 - val_loss: 2.3740 - val_accuracy: 0.3621
#
# Epoch 00045: val_accuracy did not improve from 0.41379
# Epoch 46/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3236 - accuracy: 0.9039 - val_loss: 2.3839 - val_accuracy: 0.3103
#
# Epoch 00046: val_accuracy did not improve from 0.41379
# Epoch 47/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3947 - accuracy: 0.8438 - val_loss: 2.4343 - val_accuracy: 0.3276
#
# Epoch 00047: val_accuracy did not improve from 0.41379
# Epoch 48/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3867 - accuracy: 0.8626 - val_loss: 2.4385 - val_accuracy: 0.3103
#
# Epoch 00048: val_accuracy did not improve from 0.41379
# Epoch 49/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.3480 - accuracy: 0.8866 - val_loss: 2.4949 - val_accuracy: 0.3276
#
# Epoch 00049: val_accuracy did not improve from 0.41379
# Epoch 50/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3584 - accuracy: 0.8702 - val_loss: 2.5668 - val_accuracy: 0.3276
#
# Epoch 00050: val_accuracy did not improve from 0.41379
# Epoch 51/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3471 - accuracy: 0.8895 - val_loss: 2.6168 - val_accuracy: 0.3103
#
# Epoch 00051: val_accuracy did not improve from 0.41379
# Epoch 52/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.3346 - accuracy: 0.8666 - val_loss: 2.6449 - val_accuracy: 0.3276
#
# Epoch 00052: val_accuracy did not improve from 0.41379
# Epoch 53/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.3245 - accuracy: 0.9062 - val_loss: 2.7109 - val_accuracy: 0.3276
#
# Epoch 00053: val_accuracy did not improve from 0.41379
# Epoch 54/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.3313 - accuracy: 0.9081 - val_loss: 2.7173 - val_accuracy: 0.3276
#
# Epoch 00054: val_accuracy did not improve from 0.41379
# Epoch 55/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3169 - accuracy: 0.8674 - val_loss: 2.6685 - val_accuracy: 0.3621
#
# Epoch 00055: val_accuracy did not improve from 0.41379
# Epoch 56/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.3105 - accuracy: 0.9201 - val_loss: 2.6497 - val_accuracy: 0.3448
#
# Epoch 00056: val_accuracy did not improve from 0.41379
# Epoch 57/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2997 - accuracy: 0.9051 - val_loss: 2.7117 - val_accuracy: 0.2931
#
# Epoch 00057: val_accuracy did not improve from 0.41379
# Epoch 58/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2957 - accuracy: 0.9185 - val_loss: 2.7346 - val_accuracy: 0.3621
#
# Epoch 00058: val_accuracy did not improve from 0.41379
# Epoch 59/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.3160 - accuracy: 0.8716 - val_loss: 2.7413 - val_accuracy: 0.3621
#
# Epoch 00059: val_accuracy did not improve from 0.41379
# Epoch 60/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2488 - accuracy: 0.9352 - val_loss: 2.7619 - val_accuracy: 0.4138
#
# Epoch 00060: val_accuracy did not improve from 0.41379
# Epoch 61/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.2447 - accuracy: 0.9441 - val_loss: 2.7228 - val_accuracy: 0.3966
#
# Epoch 00061: val_accuracy did not improve from 0.41379
# Epoch 62/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2730 - accuracy: 0.9394 - val_loss: 2.6628 - val_accuracy: 0.3621
#
# Epoch 00062: val_accuracy did not improve from 0.41379
# Epoch 63/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2197 - accuracy: 0.9479 - val_loss: 2.7080 - val_accuracy: 0.3448
#
# Epoch 00063: val_accuracy did not improve from 0.41379
# Epoch 64/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2487 - accuracy: 0.9394 - val_loss: 2.7778 - val_accuracy: 0.3966
#
# Epoch 00064: val_accuracy did not improve from 0.41379
# Epoch 65/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2568 - accuracy: 0.9229 - val_loss: 2.9072 - val_accuracy: 0.2586
#
# Epoch 00065: val_accuracy did not improve from 0.41379
# Epoch 66/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2563 - accuracy: 0.9253 - val_loss: 2.8448 - val_accuracy: 0.3793
#
# Epoch 00066: val_accuracy did not improve from 0.41379
# Epoch 67/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2506 - accuracy: 0.9081 - val_loss: 2.6920 - val_accuracy: 0.4310
#
# Epoch 00067: val_accuracy improved from 0.41379 to 0.43103, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 68/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.2472 - accuracy: 0.9434 - val_loss: 2.6531 - val_accuracy: 0.3793
#
# Epoch 00068: val_accuracy did not improve from 0.43103
# Epoch 69/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2529 - accuracy: 0.9130 - val_loss: 2.6771 - val_accuracy: 0.4138
#
# Epoch 00069: val_accuracy did not improve from 0.43103
# Epoch 70/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2447 - accuracy: 0.9317 - val_loss: 2.7511 - val_accuracy: 0.3966
#
# Epoch 00070: val_accuracy did not improve from 0.43103
# Epoch 71/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2566 - accuracy: 0.9109 - val_loss: 2.7746 - val_accuracy: 0.4138
#
# Epoch 00071: val_accuracy did not improve from 0.43103
# Epoch 72/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2020 - accuracy: 0.9708 - val_loss: 2.7362 - val_accuracy: 0.3793
#
# Epoch 00072: val_accuracy did not improve from 0.43103
# Epoch 73/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.2996 - accuracy: 0.9031 - val_loss: 2.6647 - val_accuracy: 0.4138
#
# Epoch 00073: val_accuracy did not improve from 0.43103
# Epoch 74/1000
# 4/4 [==============================] - 0s 60ms/step - loss: 0.2072 - accuracy: 0.9545 - val_loss: 2.7283 - val_accuracy: 0.3966
#
# Epoch 00074: val_accuracy did not improve from 0.43103
# Epoch 75/1000
# 4/4 [==============================] - 0s 58ms/step - loss: 0.2583 - accuracy: 0.8942 - val_loss: 2.6718 - val_accuracy: 0.4138
#
# Epoch 00075: val_accuracy did not improve from 0.43103
# Epoch 76/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1872 - accuracy: 0.9720 - val_loss: 2.6432 - val_accuracy: 0.4138
#
# Epoch 00076: val_accuracy did not improve from 0.43103
# Epoch 77/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2106 - accuracy: 0.9394 - val_loss: 2.5352 - val_accuracy: 0.4138
#
# Epoch 00077: val_accuracy did not improve from 0.43103
# Epoch 78/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2284 - accuracy: 0.9144 - val_loss: 2.5603 - val_accuracy: 0.3793
#
# Epoch 00078: val_accuracy did not improve from 0.43103
# Epoch 79/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2123 - accuracy: 0.9401 - val_loss: 2.8800 - val_accuracy: 0.2069
#
# Epoch 00079: val_accuracy did not improve from 0.43103
# Epoch 80/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.2326 - accuracy: 0.9182 - val_loss: 2.6034 - val_accuracy: 0.4138
#
# Epoch 00080: val_accuracy did not improve from 0.43103
# Epoch 81/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2031 - accuracy: 0.9597 - val_loss: 2.7811 - val_accuracy: 0.3448
#
# Epoch 00081: val_accuracy did not improve from 0.43103
# Epoch 82/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.2115 - accuracy: 0.9362 - val_loss: 2.5897 - val_accuracy: 0.4138
#
# Epoch 00082: val_accuracy did not improve from 0.43103
# Epoch 83/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.2016 - accuracy: 0.9387 - val_loss: 2.6989 - val_accuracy: 0.3276
#
# Epoch 00083: val_accuracy did not improve from 0.43103
# Epoch 84/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1783 - accuracy: 0.9633 - val_loss: 2.6271 - val_accuracy: 0.4310
#
# Epoch 00084: val_accuracy did not improve from 0.43103
# Epoch 85/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1655 - accuracy: 0.9691 - val_loss: 2.4912 - val_accuracy: 0.4310
#
# Epoch 00085: val_accuracy did not improve from 0.43103
# Epoch 86/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1605 - accuracy: 0.9778 - val_loss: 2.3760 - val_accuracy: 0.4310
#
# Epoch 00086: val_accuracy did not improve from 0.43103
# Epoch 87/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1811 - accuracy: 0.9672 - val_loss: 2.3998 - val_accuracy: 0.4138
#
# Epoch 00087: val_accuracy did not improve from 0.43103
# Epoch 88/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1653 - accuracy: 0.9687 - val_loss: 2.4418 - val_accuracy: 0.4138
#
# Epoch 00088: val_accuracy did not improve from 0.43103
# Epoch 89/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1813 - accuracy: 0.9613 - val_loss: 2.6474 - val_accuracy: 0.3276
#
# Epoch 00089: val_accuracy did not improve from 0.43103
# Epoch 90/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1532 - accuracy: 0.9762 - val_loss: 2.6841 - val_accuracy: 0.3276
#
# Epoch 00090: val_accuracy did not improve from 0.43103
# Epoch 91/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1469 - accuracy: 0.9858 - val_loss: 2.4747 - val_accuracy: 0.4310
#
# Epoch 00091: val_accuracy did not improve from 0.43103
# Epoch 92/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1781 - accuracy: 0.9600 - val_loss: 2.3457 - val_accuracy: 0.3966
#
# Epoch 00092: val_accuracy did not improve from 0.43103
# Epoch 93/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1420 - accuracy: 0.9719 - val_loss: 2.2598 - val_accuracy: 0.4138
#
# Epoch 00093: val_accuracy did not improve from 0.43103
# Epoch 94/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1411 - accuracy: 0.9877 - val_loss: 2.2580 - val_accuracy: 0.4138
#
# Epoch 00094: val_accuracy did not improve from 0.43103
# Epoch 95/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1427 - accuracy: 0.9858 - val_loss: 2.1523 - val_accuracy: 0.3793
#
# Epoch 00095: val_accuracy did not improve from 0.43103
# Epoch 96/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1529 - accuracy: 0.9725 - val_loss: 1.9040 - val_accuracy: 0.4483
#
# Epoch 00096: val_accuracy improved from 0.43103 to 0.44828, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 97/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1188 - accuracy: 0.9837 - val_loss: 1.8837 - val_accuracy: 0.4310
#
# Epoch 00097: val_accuracy did not improve from 0.44828
# Epoch 98/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1551 - accuracy: 0.9689 - val_loss: 1.8697 - val_accuracy: 0.4310
#
# Epoch 00098: val_accuracy did not improve from 0.44828
# Epoch 99/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1282 - accuracy: 0.9819 - val_loss: 1.8880 - val_accuracy: 0.4310
#
# Epoch 00099: val_accuracy did not improve from 0.44828
# Epoch 100/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1682 - accuracy: 0.9614 - val_loss: 1.7741 - val_accuracy: 0.4310
#
# Epoch 00100: val_accuracy did not improve from 0.44828
# Epoch 101/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1367 - accuracy: 0.9708 - val_loss: 1.7851 - val_accuracy: 0.4138
#
# Epoch 00101: val_accuracy did not improve from 0.44828
# Epoch 102/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1342 - accuracy: 0.9715 - val_loss: 1.7758 - val_accuracy: 0.4655
#
# Epoch 00102: val_accuracy improved from 0.44828 to 0.46552, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 103/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1213 - accuracy: 0.9764 - val_loss: 1.9023 - val_accuracy: 0.4655
#
# Epoch 00103: val_accuracy did not improve from 0.46552
# Epoch 104/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1731 - accuracy: 0.9510 - val_loss: 1.7489 - val_accuracy: 0.4655
#
# Epoch 00104: val_accuracy did not improve from 0.46552
# Epoch 105/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1195 - accuracy: 0.9825 - val_loss: 1.4070 - val_accuracy: 0.5172
#
# Epoch 00105: val_accuracy improved from 0.46552 to 0.51724, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 106/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1168 - accuracy: 0.9800 - val_loss: 1.3241 - val_accuracy: 0.5517
#
# Epoch 00106: val_accuracy improved from 0.51724 to 0.55172, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 107/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1151 - accuracy: 0.9791 - val_loss: 1.4622 - val_accuracy: 0.5172
#
# Epoch 00107: val_accuracy did not improve from 0.55172
# Epoch 108/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1039 - accuracy: 0.9878 - val_loss: 1.5771 - val_accuracy: 0.5000
#
# Epoch 00108: val_accuracy did not improve from 0.55172
# Epoch 109/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1530 - accuracy: 0.9715 - val_loss: 1.4447 - val_accuracy: 0.5862
#
# Epoch 00109: val_accuracy improved from 0.55172 to 0.58621, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 110/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.1384 - accuracy: 0.9600 - val_loss: 1.3557 - val_accuracy: 0.5690
#
# Epoch 00110: val_accuracy did not improve from 0.58621
# Epoch 111/1000
# 4/4 [==============================] - 0s 56ms/step - loss: 0.1027 - accuracy: 0.9847 - val_loss: 1.3471 - val_accuracy: 0.6034
#
# Epoch 00111: val_accuracy improved from 0.58621 to 0.60345, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 112/1000
# 4/4 [==============================] - 0s 64ms/step - loss: 0.1328 - accuracy: 0.9807 - val_loss: 1.2281 - val_accuracy: 0.6379
#
# Epoch 00112: val_accuracy improved from 0.60345 to 0.63793, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 113/1000
# 4/4 [==============================] - 0s 61ms/step - loss: 0.1299 - accuracy: 0.9776 - val_loss: 1.1338 - val_accuracy: 0.6552
#
# Epoch 00113: val_accuracy improved from 0.63793 to 0.65517, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 114/1000
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0962 - accuracy: 0.9882 - val_loss: 1.1037 - val_accuracy: 0.6207
#
# Epoch 00114: val_accuracy did not improve from 0.65517
# Epoch 115/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1147 - accuracy: 0.9868 - val_loss: 1.0206 - val_accuracy: 0.6207
#
# Epoch 00115: val_accuracy did not improve from 0.65517
# Epoch 116/1000
# 4/4 [==============================] - 0s 53ms/step - loss: 0.1164 - accuracy: 0.9632 - val_loss: 1.0874 - val_accuracy: 0.6552
#
# Epoch 00116: val_accuracy did not improve from 0.65517
# Epoch 117/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0871 - accuracy: 0.9925 - val_loss: 1.3179 - val_accuracy: 0.6034
#
# Epoch 00117: val_accuracy did not improve from 0.65517
# Epoch 118/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0965 - accuracy: 0.9939 - val_loss: 1.4468 - val_accuracy: 0.5345
#
# Epoch 00118: val_accuracy did not improve from 0.65517
# Epoch 119/1000
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0984 - accuracy: 0.9772 - val_loss: 1.3948 - val_accuracy: 0.5862
#
# Epoch 00119: val_accuracy did not improve from 0.65517
# Epoch 120/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1079 - accuracy: 0.9898 - val_loss: 1.3963 - val_accuracy: 0.5862
#
# Epoch 00120: val_accuracy did not improve from 0.65517
# Epoch 121/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0980 - accuracy: 0.9882 - val_loss: 1.1460 - val_accuracy: 0.6207
#
# Epoch 00121: val_accuracy did not improve from 0.65517
# Epoch 122/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1195 - accuracy: 0.9706 - val_loss: 1.0100 - val_accuracy: 0.6552
#
# Epoch 00122: val_accuracy did not improve from 0.65517
# Epoch 123/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1148 - accuracy: 0.9816 - val_loss: 0.9527 - val_accuracy: 0.6552
#
# Epoch 00123: val_accuracy did not improve from 0.65517
# Epoch 124/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1125 - accuracy: 0.9734 - val_loss: 0.9546 - val_accuracy: 0.6552
#
# Epoch 00124: val_accuracy did not improve from 0.65517
# Epoch 125/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1058 - accuracy: 0.9734 - val_loss: 0.9330 - val_accuracy: 0.6724
#
# Epoch 00125: val_accuracy improved from 0.65517 to 0.67241, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 126/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0946 - accuracy: 0.9807 - val_loss: 0.9802 - val_accuracy: 0.6552
#
# Epoch 00126: val_accuracy did not improve from 0.67241
# Epoch 127/1000
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0984 - accuracy: 0.9785 - val_loss: 1.0015 - val_accuracy: 0.6552
#
# Epoch 00127: val_accuracy did not improve from 0.67241
# Epoch 128/1000
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1171 - accuracy: 0.9592 - val_loss: 1.0626 - val_accuracy: 0.6379
#
# Epoch 00128: val_accuracy did not improve from 0.67241
# Epoch 129/1000
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0951 - accuracy: 0.9847 - val_loss: 1.3151 - val_accuracy: 0.5690
#
# Epoch 00129: val_accuracy did not improve from 0.67241
# Epoch 130/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1169 - accuracy: 0.9811 - val_loss: 1.1487 - val_accuracy: 0.6034
#
# Epoch 00130: val_accuracy did not improve from 0.67241
# Epoch 131/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0896 - accuracy: 0.9854 - val_loss: 0.8719 - val_accuracy: 0.7241
#
# Epoch 00131: val_accuracy improved from 0.67241 to 0.72414, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 132/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1040 - accuracy: 0.9830 - val_loss: 0.7601 - val_accuracy: 0.7241
#
# Epoch 00132: val_accuracy did not improve from 0.72414
# Epoch 133/1000
# 4/4 [==============================] - 0s 49ms/step - loss: 0.1101 - accuracy: 0.9646 - val_loss: 0.7567 - val_accuracy: 0.7241
#
# Epoch 00133: val_accuracy did not improve from 0.72414
# Epoch 134/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0818 - accuracy: 0.9925 - val_loss: 0.8758 - val_accuracy: 0.6897
#
# Epoch 00134: val_accuracy did not improve from 0.72414
# Epoch 135/1000
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1066 - accuracy: 0.9821 - val_loss: 0.8526 - val_accuracy: 0.6724
#
# Epoch 00135: val_accuracy did not improve from 0.72414
# Epoch 136/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.1009 - accuracy: 0.9693 - val_loss: 0.7552 - val_accuracy: 0.7414
#
# Epoch 00136: val_accuracy improved from 0.72414 to 0.74138, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 137/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0870 - accuracy: 0.9814 - val_loss: 0.6698 - val_accuracy: 0.7586
#
# Epoch 00137: val_accuracy improved from 0.74138 to 0.75862, saving model to /kaggle/tmp/checkpoint_sbj_1
# Epoch 138/1000
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0971 - accuracy: 0.9764 - val_loss: 0.6320 - val_accuracy: 0.7759
#
# ...
#
# Epoch 00246: val_accuracy did not improve from 0.84028
# Epoch 247/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0270 - accuracy: 0.9931 - val_loss: 0.8166 - val_accuracy: 0.7674
#
# Epoch 00247: val_accuracy did not improve from 0.84028
# Epoch 248/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0231 - accuracy: 0.9965 - val_loss: 0.7791 - val_accuracy: 0.7917
#
# Epoch 00248: val_accuracy did not improve from 0.84028
# Epoch 249/326
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0308 - accuracy: 0.9931 - val_loss: 0.7454 - val_accuracy: 0.7986
#
# Epoch 00249: val_accuracy did not improve from 0.84028
# Epoch 250/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0241 - accuracy: 0.9931 - val_loss: 0.7418 - val_accuracy: 0.7986
#
# Epoch 00250: val_accuracy did not improve from 0.84028
# Epoch 251/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.7465 - val_accuracy: 0.8021
#
# Epoch 00251: val_accuracy did not improve from 0.84028
# Epoch 252/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0428 - accuracy: 0.9931 - val_loss: 0.9402 - val_accuracy: 0.7326
#
# Epoch 00252: val_accuracy did not improve from 0.84028
# Epoch 253/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0284 - accuracy: 0.9965 - val_loss: 1.1554 - val_accuracy: 0.7014
#
# Epoch 00253: val_accuracy did not improve from 0.84028
# Epoch 254/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0315 - accuracy: 0.9965 - val_loss: 0.9602 - val_accuracy: 0.7361
#
# Epoch 00254: val_accuracy did not improve from 0.84028
# Epoch 255/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0221 - accuracy: 0.9965 - val_loss: 1.0098 - val_accuracy: 0.7188
#
# Epoch 00255: val_accuracy did not improve from 0.84028
# Epoch 256/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0253 - accuracy: 0.9965 - val_loss: 1.2872 - val_accuracy: 0.6979
#
# Epoch 00256: val_accuracy did not improve from 0.84028
# Epoch 257/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0362 - accuracy: 0.9931 - val_loss: 0.7446 - val_accuracy: 0.7917
#
# Epoch 00257: val_accuracy did not improve from 0.84028
# Epoch 258/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0270 - accuracy: 0.9965 - val_loss: 0.7507 - val_accuracy: 0.7847
#
# Epoch 00258: val_accuracy did not improve from 0.84028
# Epoch 259/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0425 - accuracy: 0.9826 - val_loss: 0.8256 - val_accuracy: 0.7743
#
# Epoch 00259: val_accuracy did not improve from 0.84028
# Epoch 260/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.8046 - val_accuracy: 0.7812
#
# Epoch 00260: val_accuracy did not improve from 0.84028
# Epoch 261/326
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0351 - accuracy: 0.9965 - val_loss: 0.9339 - val_accuracy: 0.7535
#
# Epoch 00261: val_accuracy did not improve from 0.84028
# Epoch 262/326
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0278 - accuracy: 0.9965 - val_loss: 0.9566 - val_accuracy: 0.7500
#
# Epoch 00262: val_accuracy did not improve from 0.84028
# Epoch 263/326
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.9047 - val_accuracy: 0.7396
#
# Epoch 00263: val_accuracy did not improve from 0.84028
# Epoch 264/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0401 - accuracy: 0.9931 - val_loss: 0.9497 - val_accuracy: 0.7639
#
# Epoch 00264: val_accuracy did not improve from 0.84028
# Epoch 265/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0385 - accuracy: 0.9826 - val_loss: 0.7960 - val_accuracy: 0.7812
#
# Epoch 00265: val_accuracy did not improve from 0.84028
# Epoch 266/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0372 - accuracy: 0.9861 - val_loss: 0.7318 - val_accuracy: 0.7917
#
# Epoch 00266: val_accuracy did not improve from 0.84028
# Epoch 267/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0355 - accuracy: 0.9896 - val_loss: 0.6378 - val_accuracy: 0.8125
#
# Epoch 00267: val_accuracy did not improve from 0.84028
# Epoch 268/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0395 - accuracy: 0.9965 - val_loss: 0.5952 - val_accuracy: 0.8125
#
# Epoch 00268: val_accuracy did not improve from 0.84028
# Epoch 269/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.6226 - val_accuracy: 0.8264
#
# Epoch 00269: val_accuracy did not improve from 0.84028
# Epoch 270/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0282 - accuracy: 0.9965 - val_loss: 0.6336 - val_accuracy: 0.8021
#
# Epoch 00270: val_accuracy did not improve from 0.84028
# Epoch 271/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0437 - accuracy: 0.9931 - val_loss: 0.7041 - val_accuracy: 0.7812
#
# Epoch 00271: val_accuracy did not improve from 0.84028
# Epoch 272/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0343 - accuracy: 0.9931 - val_loss: 0.7450 - val_accuracy: 0.8021
#
# Epoch 00272: val_accuracy did not improve from 0.84028
# Epoch 273/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0340 - accuracy: 0.9931 - val_loss: 0.7503 - val_accuracy: 0.8090
#
# Epoch 00273: val_accuracy did not improve from 0.84028
# Epoch 274/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0525 - accuracy: 0.9861 - val_loss: 0.8393 - val_accuracy: 0.7604
#
# Epoch 00274: val_accuracy did not improve from 0.84028
# Epoch 275/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0510 - accuracy: 0.9861 - val_loss: 0.7668 - val_accuracy: 0.7986
#
# Epoch 00275: val_accuracy did not improve from 0.84028
# Epoch 276/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0376 - accuracy: 0.9931 - val_loss: 0.7095 - val_accuracy: 0.8194
#
# Epoch 00276: val_accuracy did not improve from 0.84028
# Epoch 277/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0283 - accuracy: 0.9931 - val_loss: 0.6879 - val_accuracy: 0.8056
#
# Epoch 00277: val_accuracy did not improve from 0.84028
# Epoch 278/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0291 - accuracy: 0.9965 - val_loss: 0.6844 - val_accuracy: 0.8021
#
# Epoch 00278: val_accuracy did not improve from 0.84028
# Epoch 279/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0226 - accuracy: 0.9965 - val_loss: 0.7771 - val_accuracy: 0.7847
#
# Epoch 00279: val_accuracy did not improve from 0.84028
# Epoch 280/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.8204 - val_accuracy: 0.7743
#
# Epoch 00280: val_accuracy did not improve from 0.84028
# Epoch 281/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0240 - accuracy: 0.9931 - val_loss: 0.7116 - val_accuracy: 0.8021
#
# Epoch 00281: val_accuracy did not improve from 0.84028
# Epoch 282/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0298 - accuracy: 0.9931 - val_loss: 0.7010 - val_accuracy: 0.8160
#
# Epoch 00282: val_accuracy did not improve from 0.84028
# Epoch 283/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.7141 - val_accuracy: 0.8056
#
# Epoch 00283: val_accuracy did not improve from 0.84028
# Epoch 284/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0273 - accuracy: 0.9931 - val_loss: 0.7830 - val_accuracy: 0.7951
#
# Epoch 00284: val_accuracy did not improve from 0.84028
# Epoch 285/326
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.7790 - val_accuracy: 0.7986
#
# Epoch 00285: val_accuracy did not improve from 0.84028
# Epoch 286/326
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0218 - accuracy: 0.9965 - val_loss: 0.7112 - val_accuracy: 0.7951
#
# Epoch 00286: val_accuracy did not improve from 0.84028
# Epoch 287/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0180 - accuracy: 0.9931 - val_loss: 0.6776 - val_accuracy: 0.8056
#
# Epoch 00287: val_accuracy did not improve from 0.84028
# Epoch 288/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0279 - accuracy: 0.9896 - val_loss: 0.6706 - val_accuracy: 0.8090
#
# Epoch 00288: val_accuracy did not improve from 0.84028
# Epoch 289/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0244 - accuracy: 0.9965 - val_loss: 0.6443 - val_accuracy: 0.8194
#
# Epoch 00289: val_accuracy did not improve from 0.84028
# Epoch 290/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0386 - accuracy: 0.9896 - val_loss: 0.6606 - val_accuracy: 0.8160
#
# Epoch 00290: val_accuracy did not improve from 0.84028
# Epoch 291/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0279 - accuracy: 0.9965 - val_loss: 0.8930 - val_accuracy: 0.7743
#
# Epoch 00291: val_accuracy did not improve from 0.84028
# Epoch 292/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0387 - accuracy: 0.9861 - val_loss: 0.7404 - val_accuracy: 0.8056
#
# Epoch 00292: val_accuracy did not improve from 0.84028
# Epoch 293/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0371 - accuracy: 0.9965 - val_loss: 0.8178 - val_accuracy: 0.7604
#
# Epoch 00293: val_accuracy did not improve from 0.84028
# Epoch 294/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0222 - accuracy: 0.9965 - val_loss: 0.6942 - val_accuracy: 0.8194
#
# Epoch 00294: val_accuracy did not improve from 0.84028
# Epoch 295/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0348 - accuracy: 0.9896 - val_loss: 0.7164 - val_accuracy: 0.8090
#
# Epoch 00295: val_accuracy did not improve from 0.84028
# Epoch 296/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0322 - accuracy: 0.9896 - val_loss: 0.7554 - val_accuracy: 0.7986
#
# Epoch 00296: val_accuracy did not improve from 0.84028
# Epoch 297/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0274 - accuracy: 0.9896 - val_loss: 0.7466 - val_accuracy: 0.8125
#
# Epoch 00297: val_accuracy did not improve from 0.84028
# Epoch 298/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0211 - accuracy: 1.0000 - val_loss: 0.7681 - val_accuracy: 0.8090
#
# Epoch 00298: val_accuracy did not improve from 0.84028
# Epoch 299/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0262 - accuracy: 0.9931 - val_loss: 0.7680 - val_accuracy: 0.7986
#
# Epoch 00299: val_accuracy did not improve from 0.84028
# Epoch 300/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0413 - accuracy: 0.9896 - val_loss: 0.7007 - val_accuracy: 0.8056
#
# Epoch 00300: val_accuracy did not improve from 0.84028
# Epoch 301/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.7150 - val_accuracy: 0.8021
#
# Epoch 00301: val_accuracy did not improve from 0.84028
# Epoch 302/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.7776 - val_accuracy: 0.7847
#
# Epoch 00302: val_accuracy did not improve from 0.84028
# Epoch 303/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0280 - accuracy: 0.9931 - val_loss: 0.6911 - val_accuracy: 0.8056
#
# Epoch 00303: val_accuracy did not improve from 0.84028
# Epoch 304/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0331 - accuracy: 0.9931 - val_loss: 0.8020 - val_accuracy: 0.7882
#
# Epoch 00304: val_accuracy did not improve from 0.84028
# Epoch 305/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.8954 - val_accuracy: 0.7708
#
# Epoch 00305: val_accuracy did not improve from 0.84028
# Epoch 306/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0279 - accuracy: 0.9931 - val_loss: 0.8045 - val_accuracy: 0.7882
#
# Epoch 00306: val_accuracy did not improve from 0.84028
# Epoch 307/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0234 - accuracy: 0.9965 - val_loss: 0.8113 - val_accuracy: 0.7743
#
# Epoch 00307: val_accuracy did not improve from 0.84028
# Epoch 308/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0241 - accuracy: 0.9965 - val_loss: 0.7953 - val_accuracy: 0.7917
#
# Epoch 00308: val_accuracy did not improve from 0.84028
# Epoch 309/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0214 - accuracy: 0.9965 - val_loss: 0.7683 - val_accuracy: 0.7986
#
# Epoch 00309: val_accuracy did not improve from 0.84028
# Epoch 310/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.7328 - val_accuracy: 0.8160
#
# Epoch 00310: val_accuracy did not improve from 0.84028
# Epoch 311/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0192 - accuracy: 0.9965 - val_loss: 0.6823 - val_accuracy: 0.8125
#
# Epoch 00311: val_accuracy did not improve from 0.84028
# Epoch 312/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.6679 - val_accuracy: 0.8125
#
# Epoch 00312: val_accuracy did not improve from 0.84028
# Epoch 313/326
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0162 - accuracy: 0.9965 - val_loss: 0.6698 - val_accuracy: 0.8194
#
# Epoch 00313: val_accuracy did not improve from 0.84028
# Epoch 314/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0148 - accuracy: 0.9965 - val_loss: 0.6977 - val_accuracy: 0.8333
#
# Epoch 00314: val_accuracy did not improve from 0.84028
# Epoch 315/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0208 - accuracy: 0.9965 - val_loss: 0.7106 - val_accuracy: 0.8056
#
# Epoch 00315: val_accuracy did not improve from 0.84028
# Epoch 316/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.7284 - val_accuracy: 0.8056
#
# Epoch 00316: val_accuracy did not improve from 0.84028
# Epoch 317/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0260 - accuracy: 0.9965 - val_loss: 0.7389 - val_accuracy: 0.8056
#
# Epoch 00317: val_accuracy did not improve from 0.84028
# Epoch 318/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.7871 - val_accuracy: 0.7917
#
# Epoch 00318: val_accuracy did not improve from 0.84028
# Epoch 319/326
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0244 - accuracy: 0.9896 - val_loss: 0.7720 - val_accuracy: 0.7951
#
# Epoch 00319: val_accuracy did not improve from 0.84028
# Epoch 320/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0215 - accuracy: 0.9965 - val_loss: 0.8051 - val_accuracy: 0.7812
#
# Epoch 00320: val_accuracy did not improve from 0.84028
# Epoch 321/326
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0143 - accuracy: 0.9965 - val_loss: 0.7716 - val_accuracy: 0.7917
#
# Epoch 00321: val_accuracy did not improve from 0.84028
# Epoch 322/326
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0180 - accuracy: 0.9965 - val_loss: 0.7763 - val_accuracy: 0.7917
#
# Epoch 00322: val_accuracy did not improve from 0.84028
# Epoch 323/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.7523 - val_accuracy: 0.7986
#
# Epoch 00323: val_accuracy did not improve from 0.84028
# Epoch 324/326
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.7189 - val_accuracy: 0.8021
#
# Epoch 00324: val_accuracy did not improve from 0.84028
# Epoch 325/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0189 - accuracy: 0.9965 - val_loss: 0.6976 - val_accuracy: 0.8090
#
# Epoch 00325: val_accuracy did not improve from 0.84028
# Epoch 326/326
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.7036 - val_accuracy: 0.8160
#
# Epoch 00326: val_accuracy did not improve from 0.84028
# Subject accuracy: 84.030000

# %% [markdown]
# #Exp 2: Schirmeister 2017_legal

# %%
opt_args = {'lr': 0.0625*0.01,'beta_1': 0.9}
optimizer = get_optimizer('Adam',opt_args)

loss = get_loss('CategoricalCrossentropy')

metrics = ['accuracy']

callbacks_names = {'early_stopping_train':'early_stopping','checkpoint_train':'checkpoint',
                'Threshold_valid':'Threshold','checkpoint_valid':'checkpoint',
                'early_stopping_valid':'early_stopping'}


Experiment = 'schirrmeister2017_legal'
model_name = 'TCNet_fusion'

subjects = np.arange(1,10)
Acc = []
History = []
Subject = []
for sbj in subjects:
    print('Subject: {:d} of {:d}'.format(sbj,len(subjects)))

    X_train,y_train,X_valid,y_valid,fs = load_dataset(dataset_name="BNCI2014001", subject_id=sbj)


    model_args = {'nb_classes':4,'Chans':X_train.shape[1],'Samples':X_train.shape[2],'layers':2,'kernel_s':4,'filt':12,'dropout':0.3,'activation':'elu','F1':24,'D':2,'kernLength':32,'dropout_eeg':0.3}
    model = get_model(model_name,model_args)


    call_args = [{'monitor':'val_accuracy','patience':100,'min_delta':0.001,'mode':'max','verbose':1,'restore_best_weights':False},
                {'filepath':'/kaggle/tmp/checkpoint_sbj_'+str(sbj),'save_format':'tf','monitor':'val_accuracy','verbose':1,'save_weights_only':True,'save_best_only':True},
                {'threshold':None},
                {'filepath':'/kaggle/tmp/checkpoint_2_sbj_'+str(sbj),'save_format':'tf','monitor':'val_accuracy','verbose':1,'save_weights_only':True,'save_best_only':True},
                {'monitor':'val_accuracy','patience':None,'min_delta':0.001,'mode':'max','verbose':1,'restore_best_weights':True}]
                
    callbacks = get_callbacks(callbacks_names,call_args)

    cv = train_model_cv(model,optimizer,loss,metrics,callbacks=callbacks)

    history = cv.fit_validation(X_train,y_train,X_val=X_valid,y_val=y_valid,batch_size=64,epochs=1000,verbose=1,val_mode=Experiment)
    acc = cv.get_accuracy()
    print('Subject accuracy: {:f}'.format(acc))
    Acc.append(acc)
    History.append(History)
    Subject.append(sbj)

    results = {}
    results['subject'] = Subject
    results['history'] = History
    results['accuracy'] = Acc

    with open('Results_BCI2a_'+Experiment+'_'+model_name+'.p','wb') as handle:
        pickle.dump(results,handle)
    
    del cv,callbacks

# %% [markdown]
# # Exp 3: Schirmeister 2021

# %%
opt_args = {'lr': 0.0625*0.01,'beta_1': 0.9}
optimizer = get_optimizer('Adam',opt_args)

loss = get_loss('CategoricalCrossentropy')

metrics = ['accuracy']

callbacks_names = {'checkpoint_valid':'checkpoint',
                   'early_stopping_valid':'early_stopping'}


Experiment = 'schirrmeister2021'
model_name = 'TCNet_fusion'

subjects = np.arange(1,10)
Acc = []
History = []
Subject = []
for sbj in subjects:
    print('Subject: {:d} of {:d}'.format(sbj,len(subjects)))

    X_train,y_train,X_valid,y_valid,fs = load_dataset(dataset_name="BNCI2014001", subject_id=sbj) 

    model_args = {'nb_classes':4,'Chans':X_train.shape[1],'Samples':X_train.shape[2],'layers':2,'kernel_s':4,'filt':12,'dropout':0.3,'activation':'elu','F1':24,'D':2,'kernLength':32,'dropout_eeg':0.3}
    model = get_model(model_name,model_args)    
    
    

    call_args = [
            {'filepath':'/kaggle/tmp/checkpoint_'+str(sbj),
            'save_format':'tf',
            'monitor':'val_accuracy',
            'verbose':1,
            'save_weights_only':True,
            'save_best_only':True},
            {'monitor':'val_accuracy',
            'patience':100,
            'min_delta':0.001,
            'mode':'max',
            'verbose':1,
            'restore_best_weights':True}]
                
    callbacks = get_callbacks(callbacks_names,call_args)

    cv = train_model_cv(model,optimizer,loss,metrics,callbacks=callbacks)

    history = cv.fit_validation(X_train,y_train,X_val=X_valid,y_val=y_valid,batch_size=64,epochs=1000,verbose=1,val_mode=Experiment)
    acc = cv.get_accuracy()
    print('Subject accuracy: {:f}'.format(acc))
    Acc.append(acc)
    History.append(History)
    Subject.append(sbj)

    results = {}
    results['subject'] = Subject
    results['history'] = History
    results['accuracy'] = Acc

    with open('Results_BCI2a_'+Experiment+'_'+model_name+'.p','wb') as handle:
        pickle.dump(results,handle)
    
    del cv,callbacks

# %% [markdown]
# # Exp 4: 4-fold CV

# %%
opt_args = {'lr': 0.0625*0.01,'beta_1': 0.9}
optimizer = get_optimizer('Adam',opt_args)

loss = get_loss('CategoricalCrossentropy')

metrics = ['accuracy']

callbacks_names = {'checkpoint_train1':'checkpoint','checkpoint_train2':'checkpoint','checkpoint_train3':'checkpoint','checkpoint_train4':'checkpoint'}


Experiment = 'lawhern2018'
model_name = 'TCNet_fusion'

fs_new = 128
subjects = np.arange(1,10)
Acc = []
History = []
Subject = []
for sbj in subjects:
    print('Subject: {:d} of {:d}'.format(sbj,len(subjects)))

    X_train,y_train,X_valid,y_valid,fs = load_dataset(dataset_name="BNCI2014001", subject_id=sbj)
    X_train = resample(X_train,int((X_train.shape[-2]/fs)*fs_new),axis=-2)    
    X_valid = resample(X_valid,int((X_valid.shape[-2]/fs)*fs_new),axis=-2)    

    
    model_args = {'nb_classes':4,'Chans':X_train.shape[1],'Samples':X_train.shape[2],'layers':2,'kernel_s':4,'filt':12,'dropout':0.3,'activation':'elu','F1':24,'D':2,'kernLength':32,'dropout_eeg':0.3}
    model = get_model(model_name,model_args)    

    call_args = [
            
            {'filepath':'/kaggle/tmp/checkpoint1_'+str(sbj),
            'save_format':'tf',
            'monitor':'val_accuracy',
            'verbose':1,
            'save_weights_only':True,
            'save_best_only':True},
             {'filepath':'/kaggle/tmp/checkpoint2_'+str(sbj),
            'save_format':'tf',
            'monitor':'val_accuracy',
            'verbose':1,
            'save_weights_only':True,
            'save_best_only':True},
             {'filepath':'/kaggle/tmp/checkpoint3_'+str(sbj),
            'save_format':'tf',
            'monitor':'val_accuracy',
            'verbose':1,
            'save_weights_only':True,
            'save_best_only':True},
             {'filepath':'/kaggle/tmp/checkpoint4_'+str(sbj),
            'save_format':'tf',
            'monitor':'val_accuracy',
            'verbose':1,
            'save_weights_only':True,
            'save_best_only':True}]
                
    callbacks = get_callbacks(callbacks_names,call_args)

    cv = train_model_cv(model,optimizer,loss,metrics,callbacks=callbacks)

    history = cv.fit_validation(X_train,y_train,X_val=X_valid,y_val=y_valid,batch_size=64,epochs=1000,verbose=1,val_mode=Experiment)
    acc = cv.get_accuracy()
    print('Subject accuracy: {:f}'.format(acc))
    Acc.append(acc)
    History.append(History)
    Subject.append(sbj)

    results = {}
    results['subject'] = Subject
    results['history'] = History
    results['accuracy'] = Acc

    with open('Results_BCI2a_'+Experiment+'_'+model_name+'.p','wb') as handle:
        pickle.dump(results,handle)
    
    del cv,callbacks
